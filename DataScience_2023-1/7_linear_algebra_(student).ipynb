# %% [markdown]
# # 데이터사이언스 (0010085001)
#
# ## Exercise 7: Linear Algebra
#
# In this excercise, we plan to perform from the basic usage of linear algebra functions to the application of SVD.

# %% [markdown]
# ### 1. Basic Linear Algebra
#
# #### option 1) numpy.linalg

# %% [markdown]
# ##### np.dot / mp.matmul
#
# Dot product of two arrays.
# - https://numpy.org/doc/stable/reference/generated/numpy.dot.html
#
# Matrix product of two arrays
# - https://numpy.org/doc/stable/reference/generated/numpy.matmul.html

# %%
import numpy as np

# %%
# Scalar product of 3 and 4
results = np.dot(3,4)
print(results)
# Out:
# 12

# %%
# Dot product of [[1, 0], [0, 1]] and [[4, 1], [2, 2]]
a = np.array([[1, 0], [0, 1]])
b = np.array([[4, 1], [2, 2]])
results = np.dot(a, b)
print(results)
# Out:
# [[4 1]
#  [2 2]]

# %%
# 2D array matrix product of [[1, 0], [0, 1]] and [[4, 1], [0, 1]]
a = np.array([[1, 0],
              [0, 1]])
b = np.array([[4, 1],
              [0, 1]])
results = np.matmul(a,b)
print(results)
# Out:
# [[4 1]
#  [0 1]]

# %%
# 2D array and 1D array matrix product of [[1, 0], [0, 1]] and [1, 2]
a = np.array([[1, 0],
              [0, 1]])
b = np.array([1,2])
results = np.matmul(a,b)
print(results)

# @ operator can be used as a shorthand for np.matmul on ndarrays
results = a@b
print(results)
# Out:
# [1 2]
# [1 2]

# %% [markdown]
# ##### np.multiply
#
# Multiply arguments element-wise
#
# - https://numpy.org/doc/stable/reference/generated/numpy.multiply.html#numpy-multiply

# %%
# Multiply 2.0 and 4.0
results = 
print(results)

# %%
# Element-wise multiplication of [[1, 0], [0, 1]] and [[4, 1], [2, 2]]
a = 
b = 
results = 
print(results)

# %%
# Element-wise multiplication of [[0., 1., 2.], [3., 4., 5.,], [6., 7., 8.,]] and [0., 1., 2]
x1 = 
x2 = 
results = 
print(results)

# %% [markdown]
# ##### np.inner
#
# Inner product of two arrays
# - https://numpy.org/doc/stable/reference/generated/numpy.inner.html

# %%
# Inner product of two vectors [1, 2, 3] and [0, 1, 0]
a = 
b = 
results = 
print(results)

# %%
# Inner product of multidimensional vectors
a = 
b = 
results = 
print(results)

# %%
# Inner product of multidimensional vectors
a = 
b = 
results = 
print(results)

# %% [markdown]
# ##### np.linalg.norm
#
# Matrix or vector norm
# - https://numpy.org/doc/stable/reference/generated/numpy.linalg.norm.html#numpy-linalg-norm

# %%
from numpy import linalg as LA

# %%
# Set a and b as follows:
a = np.arange(9) - 4
print(a)

b = a.reshape((3,3))
print(b)
# Out:
# [-4 -3 -2 -1  0  1  2  3  4]
# [[-4 -3 -2]
#  [-1  0  1]
#  [ 2  3  4]]

# %%
# Calculate norm of a and b
norm_a = 
norm_b = 
print(norm_a)
print(norm_b)

# %%
# Calculate Frobenius norm of b
fro_norm_b = 
print(fro_norm_b)

# %%
# Calculate infinity norm of a and b
inf_norm_a = 
inf_norm_b = 
print(inf_norm_a)
print(inf_norm_b)

# %%
# Calculate L1 norm of a and b
norm1_a = 
norm1_b = 
print(norm1_a)
print(norm1_b)

# %%
# Calculate L2 norm of a and b
norm2_a = 
norm2_b = 
print(norm2_a)
print(norm2_b)

# %% [markdown]
# #### option 2) scipy.linalg
# - https://docs.scipy.org/doc/scipy/reference/linalg.html#module-scipy.linalg

# %%
import numpy as np
from scipy import linalg

# %% [markdown]
# ##### scipy.linalg.inv
#
# Compute the inverse of matrix
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.linalg.inv.html

# %%
# Compute the invers of [[1., 2.], [3., 4.]]
a = 
inv_a = 
print(inv_a)

# Compute the multiplication between original and inverse matrices
product = 
print(product)

# %% [markdown]
# ##### scipy.linalg.det
#
# Compute the determinant of a matrix
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.linalg.det.html#scipy.linalg.det

# %%
# Compute the determinant of [[1,2,3], [4,5,6], [7,8,9]])
a = 
det_a = 
print(det_a)

# Compute the determinant of [[0,2,3], [4,5,6], [7,8,9]]
b = 
det_b = 
print(det_b)

# %% [markdown]
# ##### scipy.linalg.norm
#
# Matrix or vector norm
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.linalg.norm.html

# %%
# Set a and b as follows:
a = np.arange(9) - 4
print(a)

b = a.reshape((3, 3))
print(b)

# %%
# Compute norm of a and b
norm_a = 
print(norm_a)

norm_b = 
print(norm_b)

# %%
# Compute frobenius norm of b
norm_b_fro = 
print(norm_b_fro)

# %%
# Compute infinity norm of a and b
norm_inf_a = 
norm_inf_b = 
print(norm_inf_a)
print(norm_inf_b)

# %%
# Compute L1 norm of a
norm_l1_a = 
print(norm_l1_a)

# Compute L2 norm of b
norm_l2_b = linalg.norm(b, 2)
print(norm_l2_b)

# %% [markdown]
# ### 2. Eigenvalue

# %% [markdown]
# ##### np.linalg.eig
#
# Compute the eigenvalues and right eigenvectors of a square array
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.linalg.eig.html#scipy-linalg-eig

# %%
from numpy import linalg as LA
from scipy import linalg

# %%
# Compute eigenvalues of [[1, -1], [1, 1]]
a = [[1, -1], [1, 1]]
w, v = LA.eig(a)
print(w)
print(v)
# Out:
# [1.+1.j 1.-1.j]
# [[0.70710678+0.j         0.70710678-0.j        ]
#  [0.        -0.70710678j 0.        +0.70710678j]]

# %% [markdown]
# ##### scipy.linalg.eigvals
#
# Compute eigenvalues from an ordinary or generalized eigenvalue problem
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.linalg.eigvals.html

# %%
# Compute eigenvalues of [[2, 1], [1, 2]]
a = [[2, 1], [1, 2]]
eigens = linalg.eigvals(a)
print(eigens)
# Out:
# [3.+0.j 1.+0.j]

# %% [markdown]
# ### 3. Singular Value Decomposition (SVD)

# %% [markdown]
# ##### numpy.linalg.svd
#
# Singular Value Decomposition
# - https://numpy.org/doc/stable/reference/generated/numpy.linalg.svd.html#numpy.linalg.svd

# %%
# Random number generation
a = np.random.randn(9, 6) + 1j*np.random.randn(9, 6)
a
# Out:
# array([[-0.77279807-0.33483284j, -1.38677856-0.19241145j,
#          0.56702521+0.06484874j,  0.70134487-2.03233138j,
#         -0.41853726-0.63022795j,  1.42527019-0.11167258j],
#        [-1.10703909-1.65287479j,  0.13388462-0.47935526j,
#         -0.42096084-1.37491435j,  0.6757288 +0.59731513j,
#          0.12671183-0.66345994j, -0.96831947-0.24591158j],
#        [ 0.01605666-0.01793901j, -0.04761135+0.57752405j,
#          1.66321269-0.24772647j,  0.45770387+1.3554317j ,
#          0.26672095+2.23233434j,  0.24728952+0.5143561j ],
#        [ 0.77514288+0.03801467j, -0.52518491+0.85468281j,
#          0.86547897+0.69462145j,  0.00805864-0.4951368j ,
#         -0.31176862-1.39039623j,  1.93895745+0.89493251j],
#        [-1.05876922-1.67690553j,  0.36204853+0.72077938j,
#         -0.49606626+0.40184594j,  0.26466782+2.0257734j ,
#         -1.05284356-0.82127956j,  0.451244  -0.67060102j],
#        [ 0.36555883-1.61821139j, -0.76268669+0.55508145j,
#          0.1371315 +1.32682572j, -0.04311379-0.56606577j,
#         -1.00615554+2.10369885j,  1.07037293+0.76841293j],
#        [ 0.81266502-0.41126485j,  0.40373391-0.63512235j,
#         -1.04272181+1.04001744j, -0.84018   -0.76932499j,
#         -0.51320109+0.54139189j,  1.83557258+1.05962222j],
#        [-0.31459573-1.09105546j,  0.95976816-0.26875198j,
#         -1.13515053-2.03626037j,  0.0275502 +0.22694094j,
#         -2.6199715 -0.74438287j,  0.40579156+0.8285333j ],
#        [ 0.73508752+0.50015629j,  2.02178848+2.28887965j,
#          1.18895804-1.44808053j, -2.13347227+0.44381809j,
#         -0.87339959+0.04058166j,  0.5268412 -1.14958362j]])

# %%
# SVD on the matrix a
u, s, vh = LA.svd(a)
print(u.shape, s.shape, vh.shape)
print(s)
# Out:
# (9, 9) (6,) (6, 6)
# [6.48745296 5.5051145  4.2434401  3.40501677 2.48199172 1.44789129]

# %% [markdown]
# ##### scipy.linalg.svd
#
# Singular Value Decomposition
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.linalg.svd.html#scipy.linalg.svd

# %%
# Random number generation
rng = np.random.default_rng()
m, n = 9, 6
a = rng.standard_normal((m, n)) + 1.j*rng.standard_normal((m, n))

# %%
# SVD on the matrix a
u, s, vh = 
print(u.shape,  s.shape, vh.shape)
print(s)

# %% [markdown]
# ### 3. Dimensionality Reduction with SVD
#
# TruncatedSVD is sometimes called Latent Semantic Analysis (LSA)
# - https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.decomposition import TruncatedSVD, PCA

# %%
# Load iris dataset
iris = load_iris()
dataset= iris.data
print(dataset.shape)
# Out:
# (150, 4)

# %%
# Call truncated SVD
tsvd = TruncatedSVD(n_components=2)

print('Before the Truncated SVD: ', dataset.shape)

# Perform truncated SVD on iris dataset
tsvd.fit_transform(dataset)
print('After the Truncated SVD: ', dataset.shape)
# Out:
# Before the Truncated SVD:  (150, 4)
# After the Truncated SVD:  (150, 4)

# %%
# Visualize reduced dataset
plt.scatter(x=dataset[:,0], 
            y= dataset[:,1], 
            c= iris.target)
plt.xlabel('TruncatedSVD Component 1')
plt.ylabel('TruncatedSVD Component 2')
# Out:
# Text(0, 0.5, 'TruncatedSVD Component 2')

# %% [markdown]
# ### 4. Image Reconstruction with SVD

# %%
 pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
#      ---------------------------------------- 38.2/38.2 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in c:\users\gkdms\anaconda3\lib\site-packages (from opencv-python) (1.23.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.72
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load image  
img = cv2.imread('./soo.jpg')
print('original image shape: ', img.shape)
# Out:
# original image shape:  (468, 700, 3)

# %%
# Resize image (optional)
img = cv2.resize(img, dsize=(456, 684))
print('resized image shape: ', img.shape)
# Out:
# resized image shape:  (684, 456, 3)

# %%
# Converting the image into gray scale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print('gray image shape: ', img_gray.shape)
# Out:
# gray image shape:  (684, 456)

# %%
# Calculating the SVD
u, s, v = np.linalg.svd(img_gray, full_matrices=False)
s_diag = np.diag(s)
print(s_diag.shape)
# Inspect shapes of the matrices
print(u.shape, s.shape, v.shape)
print(s[:10])
# Out:
# (456, 456)
# (684, 456) (456,) (456, 456)
# [72629.84945545 16964.79952738  8258.50173866  7478.07218235
#   6046.98134644  5566.09090663  4811.75556584  3845.77720693
#   3693.73775331  3234.0437168 ]

# %%
# Calculate the ratio of singular values
# A singular value is the square root of an eigenvalue
var_explained = np.round(s**2 / np.sum(s**2), decimals=6)

# Variance explained top Singular vectors
print('Top 20 singular values')
sns.barplot(x=list(range(1, 21)),
            y=var_explained[0:20], 
            color="dodgerblue")

plt.title('Variance Explained Graph')
plt.xlabel('Singular Vector', fontsize=16)
plt.ylabel('Variance Explained', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Top 20 singular values

# %%
# Reconstruct using all components
# img  ~= u * s * v^t
# low_rank = u[:, :684] @ np.diag(s[:684]) @ v[:684, :]
row_rank = u @ np.diag(s) @ v
print(row_rank.shape)

# plt.figure()
# plt.imshow(row_rank)
# Out:
# (684, 456)

# %%
# Save image
cv2.imwrite('soo_gray.jpg', img_gray)
cv2.imwrite('soo_svd.jpg', low_rank)
# Out:
# True

# %%
# plot figure
plt.figure()

# Plot reconstructed image
plt.subplot(1, 2, 1)
plt.imshow(row_rank)

# Plot original image
plt.subplot(1, 2, 2)
plt.imshow(img_gray, cmap='gray')

# %%
# Plot images with different number of components
comps = [684, 1, 5, 10, 15, 20]
plt.figure(figsize=(12, 6))

# Reconstruct using all components
# img  ~= u * s * v^t
for i in range(len(comps)):
    low_rank = cv2.imread('./soo_gray.jpg')
      
    if(i == 0):
        plt.subplot(2, 3, i+1),
        plt.imshow(low_rank, cmap='gray'),
        plt.title('Actual Image with n_components = {}'.format(comps[i]))
    else:
        plt.subplot(2, 3, i+1),
        plt.imshow(low_rank, cmap='gray'),
        plt.title('n_components = {}'.format(comps[i]))
        cv2.imwrite('newjeans_svd_{}.jpg'.format(comps[i]), low_rank)
